# %%
import pandas as pd
from os import path

# %%
# Hier euren Pfad zur CSV einfügen
path = "C:/Users/lorga/Desktop/Parlament/data/merged.csv"
meps_df = pd.read_csv(path, sep = ";")
geonames_df = pd.read_csv("C:/Users/lorga/Desktop/Parlament/data/geonames.csv", sep = ";")
geonames_df["Name"] = geonames_df["Name"].str.lower()
geonames_df["Alternate Names"] = geonames_df["Alternate Names"].str.lower()
alt_geonames_df = geonames_df.loc[geonames_df["Alternate Names"].notna()]

# %%
gender_percentages_df = pd.DataFrame(meps_df.value_counts("gender"))
gender_percentages_df = gender_percentages_df.reset_index().rename(columns = {0: "count"})
gender_percentages_df["percentage"] = gender_percentages_df["count"] / gender_percentages_df["count"].sum()
gender_percentages_df
# Out:
#    gender  count  percentage
# 0    MALE    425    0.601132
# 1  FEMALE    282    0.398868

# %%
gender_dict = {}
for faction in set(meps_df["faction"].tolist()):
    faction_df = meps_df.loc[meps_df["faction"] == faction]
    female_count = len(faction_df.loc[faction_df["gender"] == "FEMALE"].index)
    if len(faction_df.index > 0):
        female_percentage = female_count / len(faction_df.index) * 100
        gender_dict[faction] = female_percentage
faction_percentage_df = pd.DataFrame.from_dict([gender_dict]).transpose()
faction_percentage_df = faction_percentage_df.rename(columns = {0: "Percentage of women"})
faction_percentage_df.sort_values("Percentage of women")
# Out:
#                                                     Percentage of women
# European Conservatives and Reformists Group                   27.941176
# Non-attached Members                                          31.372549
# Identity and Democracy Group                                  37.931034
# Group of the European People's Party (Christian...            37.988827
# Group of the Progressive Alliance of Socialists...            42.253521
# Renew Europe Group                                            43.000000
# The Left group in the European Parliament - GUE...            48.648649
# Group of the Greens/European Free Alliance                    50.000000

# %%
meps_df.head()
# Out:
#    identifier               name  familyName  givenName  gender citizenship  \
# 0       28150          Kinga Gál         Gál      Kinga  FEMALE         HUN
# 1      197425       Ralf Seekatz     Seekatz       Ralf    MALE         DEU
# 2      190517  Martin Schirdewan  Schirdewan     Martin    MALE         DEU
# 3      197518  Krzysztof Jurgiel     Jurgiel  Krzysztof    MALE         POL
# 4      197691  Mathilde Androuët    Androuët   Mathilde  FEMALE         FRA
#
#                                              faction  \
# 0                               Non-attached Members
# 1  Group of the European People's Party (Christia...
# 2  The Left group in the European Parliament - GU...
# 3        European Conservatives and Reformists Group
# 4                       Identity and Democracy Group
#
#                      memberships       born_place  born_day  born_month  \
# 0       AFET,D-CN,EMPL,DACP,DPAC      Cluj-Napoca         6           9
# ...

# %%
org_list = []
for list_entry in meps_df["memberships"].tolist():
    if list_entry:
        for entry in str(list_entry).split(","):
            org_list.append(entry)
list(set(org_list))
org_list.remove("nan")
org_list
# Out:
# ['AFET',
#  'D-CN',
#  'EMPL',
#  'DACP',
#  'DPAC',
#  'ECON',
#  'D-IN',
#  'DCAS',
#  'INTA',
#  'EMPL',
#  'D-RU',
#  'D-CA',
#  'ECON',
#  'AGRI',
#  'D-TR',
#  'REGI',
#  'D-IQ',
#  'ENVI',
#  'DASE',
#  'AGRI',
#  'DACP',
#  'DAFR',
#  'DEVE',
#  'PECH',
#  'FEMM',
#  'D-ZA',
#  'EMPL',
#  'DKOR',
#  'AFET',
#  'DROI',
#  'D-TR',
#  'LIBE',
#  'SEDE',
#  'D-AL',
#  'DASE',
#  'EMPL',
#  'TRAN',
#  'ENVI',
#  'PETI',
#  'D-IL',
#  'AFET',
#  'SANT',
#  'ENVI',
#  'ECON',
#  'FISC',
#  'DARP',
#  'DSAS',
#  'DMED',
#  'BUDG',
#  'DASE',
#  'ECON',
#  'ITRE',
#  'DAND',
#  'DLAT',
#  'ECON',
#  'FISC',
#  'D-US',
#  'INTA',
#  'DCAM',
#  'ENVI',
#  'PETI',
#  'DSCA',
#  'DEPA',
#  'AGRI',
#  'D-MD',
#  'PETI',
#  'ITRE',
#  'FISC',
#  'ECON',
#  'EMPL',
#  'DEEA',
#  'D-IN',
#  'ITRE',
#  'FEMM',
#  'D-ZA',
#  'ITRE',
#  'D-US',
#  'ECON',
#  'IMCO',
#  'DAND',
#  'DASE',
#  'DLAT',
#  'ENVI',
#  'INTA',
#  'TRAN',
#  'PECH',
#  'DPAL',
#  'DACP',
#  'DCAB',
#  'ENVI',
# ...

# %%
def filter_percentage_df(column, filter_list, meps_df):
    gender_dict = {}
    non_na_df = meps_df.loc[meps_df[column].notna()]
    for filter_entry in filter_list:
        filter_df = non_na_df.loc[non_na_df[column].str.contains(filter_entry)]
        female_count = len(filter_df.loc[filter_df["gender"] == "FEMALE"].index)
        if len(filter_df.index > 0):
            female_percentage = female_count / len(filter_df.index) * 100
            gender_dict[filter_entry] = female_percentage
    filter_percentage_df = pd.DataFrame.from_dict([gender_dict]).transpose()
    filter_percentage_df = filter_percentage_df.rename(columns = {0: "Percentage of women"})
    return filter_percentage_df.sort_values("Percentage of women")
committee_list = [org for org in org_list if not "D-" in org]
committee_percentage_df = filter_percentage_df("memberships", committee_list, meps_df)
committee_percentage_df
# Out:
#       Percentage of women
# AFCO            19.642857
# DARP            20.000000
# DPAC            25.000000
# DSEE            25.000000
# BUDG            26.923077
# SEDE            27.586207
# AFET            28.571429
# DCAS            29.411765
# FISC            30.769231
# ECON            31.304348
# DNAT            31.578947
# JURI            33.333333
# DKOR            33.333333
# DMER            34.210526
# PETI            34.848485
# DMAS            36.111111
# CONT            36.363636
# DCAR            36.363636
# ITRE            36.774194
# DASE            37.037037
# TRAN            37.113402
# INTA            37.647059
# DEPA            37.777778
# DROI            38.596491
# DAFR            38.775510
# DACP            39.024390
# AGRI            39.784946
# DLAT            40.000000
# DEEA            40.000000
# DCAM            40.740741
# DMAG            41.666667
# REGI            42.168675
# PECH            42.307692
# DMED            42.352941
# ...

# %% [markdown]
# Where were MEPs born?

# %%
def native_born_counter(birthplaces, home_country_code):
    eu_country_codes = ["AT", "BE", "BG", "CY", "CZ", "DE", "DK", "EE", "ES", "FI",
                       "FR", "GR", "HR", "HU", "IE", "IT", "LT", "LU", "LV", "MT", "NL", "PL",
                       "PT", "RO", "SE", "SI", "SK"]
    other_country_codes = eu_country_codes
    other_country_codes.remove(home_country_code)
    counter = 0
    success = 0
    native_born = 0
    eu_born = 0
    non_native_birthplaces = []
    for place_start in birthplaces:
        counter += 1
        # clean place name
        place = str(place_start).lower()
        if place != "nan":
            for sign in ["(", "/", "-", ","]:
                place = place.split(sign)[0].strip()
            country_codes = geonames_df.loc[geonames_df["Name"] == place]["Country Code"].values
            if len(country_codes) > 0:
                success += 1
                if home_country_code in country_codes:
                    native_born += 1
                elif any(country_code in country_codes for country_code in eu_country_codes):
                    eu_born += 1
                elif geonames_df["Alternate Names"].str.contains(place, na = False).any():
                    alt_country_codes = alt_geonames_df.loc[alt_geonames_df["Alternate Names"].str.contains(place)].values
                    if len(alt_country_codes) > 0:
                        if home_country_code in alt_country_codes:
                            native_born += 1
                        elif any(country_code in alt_country_codes for country_code in other_country_codes):
                            eu_born += 1
                        else:
                            non_native_birthplaces.append(place)
            elif geonames_df["Alternate Names"].str.contains(place, na = False).any():
                alt_country_codes = alt_geonames_df.loc[alt_geonames_df["Alternate Names"].str.contains(place)].values
                if len(alt_country_codes) > 0:
                    success += 1
                    if home_country_code in alt_country_codes:
                        native_born += 1
                    elif any(country_code in alt_country_codes for country_code in other_country_codes):
                        eu_born += 1
                    else:
                        non_native_birthplaces.append(place)
                else:
                    print(place_start, place)
            # place names not being recognised
            #else:
            #   print(place_start, place)
    return success, native_born, eu_born, counter, non_native_birthplaces

# %%
mep_origin_dict = {}
for country in set(meps_df["country"].tolist()):
    mep_origin_dict[country] = []
    country_meps_df = meps_df.loc[meps_df["country"] == country]
    birthplaces = country_meps_df["born_place"].tolist()
    success, native_born, eu_born, counter, non_native_birthplaces = native_born_counter(birthplaces, country)
    mep_origin_dict[country] = [country, 
                             round((success / counter * 100), 2), 
                             round((native_born / success * 100), 2), 
                             round((eu_born / success * 100), 2), 
                             round(((success - native_born - eu_born) / success * 100), 2)]
mep_origin_df = pd.DataFrame.from_dict(mep_origin_dict)
mep_origin_df = mep_origin_df.transpose()
mep_origin_df = mep_origin_df.drop(columns = [0])
mep_origin_df = mep_origin_df.rename(columns = {1: "Identified", 2: "Native-born", 3: "EU-born", 4: "Foreign-born"})
mep_origin_df.head()
# Out:
#    Identified Native-born EU-born Foreign-born
# NL      82.76       95.83    4.17          0.0
# BE      95.24       100.0     0.0          0.0
# IT      97.37       90.54    9.46          0.0
# EE      100.0       100.0     0.0          0.0
# LV       87.5       85.71   14.29          0.0

# %%
mep_origin_df.sort_values(by = ["Native-born"])
# Out:
#    Identified Native-born EU-born Foreign-born
# HU      95.24        70.0    20.0         10.0
# SE      76.19       81.25     0.0        18.75
# BG      100.0       82.35    5.88        11.76
# HR      100.0       83.33    8.33         8.33
# LU      100.0       83.33   16.67          0.0
# LV       87.5       85.71   14.29          0.0
# IE      100.0       85.71     0.0        14.29
# LT      81.82       88.89     0.0        11.11
# PT      86.36       89.47     0.0        10.53
# GR      100.0       90.48    4.76         4.76
# IT      97.37       90.54    9.46          0.0
# DK      78.57       90.91     0.0         9.09
# ES      96.61       92.98    1.75         5.26
# FR      93.67       93.24    4.05          2.7
# AT      89.47       94.12    5.88          0.0
# DE      97.92       95.74    2.13         2.13
# NL      82.76       95.83    4.17          0.0
# RO      90.91       96.67     0.0         3.33
# PL      86.79       97.83     0.0         2.17
# ...
